# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.load('D:\One_한양대학교\private object minsu\coding\data\\brain_2025\emo_fnirs.npy')
b = np.load('D:\One_한양대학교\private object minsu\coding\data\\brain_2025\emo_fnirs_1.npy')[:,:,:,371:]

# %%
i = 12
plt.figure(figsize=(20,3))
plt.plot(a[0,0,i])
# plt.plot(b[0,0,i])
